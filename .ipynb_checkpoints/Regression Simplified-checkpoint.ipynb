# %% [markdown]
# # Import

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
import seaborn as sns
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

## Shap
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";funct
# ...

# %% [markdown]
# # Load Data

# %%
dataset= pd.read_csv('wine.csv')

# %% [markdown]
# # Exploration and Preprocesing

# %%
dataset.shape
# Out:
# (4898, 12)

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
# fixed acidity           4898 non-null float64
# volatile acidity        4898 non-null float64
# citric acid             4898 non-null float64
# residual sugar          4898 non-null float64
# chlorides               4898 non-null float64
# free sulfur dioxide     4898 non-null float64
# total sulfur dioxide    4898 non-null float64
# density                 4898 non-null float64
# pH                      4898 non-null float64
# sulphates               4898 non-null float64
# alcohol                 4898 non-null float64
# quality                 4898 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
dataset.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
results= dataset

# %%
def missing_zero_values_table(df):
        zero_val = (df == 0.00).astype(int).sum(axis=0)
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mz_table = pd.concat([zero_val, mis_val, mis_val_percent], axis=1)
        mz_table = mz_table.rename(
        columns = {0 : 'Zero Values', 1 : 'Missing Values', 2 : '% of Total Values'})
        mz_table['Total Zero Missing Values'] = mz_table['Zero Values'] + mz_table['Missing Values']
        mz_table['% Total Zero Missing Values'] = 100 * mz_table['Total Zero Missing Values'] / len(df)
        mz_table['Data Type'] = df.dtypes
        mz_table = mz_table[
            mz_table.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns and " + str(df.shape[0]) + " Rows.\n"      
            "There are " + str(mz_table.shape[0]) +
              " columns that have missing values.")
#         mz_table.to_excel('D:/sampledata/missing_and_zero_values.xlsx', freeze_panes=(1,0), index = False)
        return mz_table

# %%
## No missing values, or else above function will give us nice break down of missing values

# %% [markdown]
# ## Imputing missing values

# %%
#dataset.isnull().any()  check to see if anycolumn has missingvalues
#dataset = dataset.fillna(method='ffill') # will remove any rows with missing values
#dataset = data_clust.fillna(0) # change all the missing values to 0

# %% [markdown]
# ### Mean/Median imputation

# %%
# Create an imputer object that looks for 'Nan' values, 
#then replaces them with the mean value of the feature by columns (axis=0)
#mean_imputer = Imputer(missing_values='NaN', strategy='mean', axis=0)
# train imputer
#mean_imputer=mean_imputer.fit(dataset)
#Apply imputer
#imputed_dataset= mean_imputer.fit(dataset)

# %%
plt.style.use('dark_background')
sns.heatmap(dataset.corr())

# %%
corr_matrix = dataset.corr()
corr_matrix
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
dataset.hist(bins=50, figsize=(20,15))
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.tight_layout()
seabornInstance.distplot(dataset['quality'])

# %% [markdown]
# As we can observe that most of the time the value is either 5 or 6.

# %% [markdown]
# ## Scale the data if required

# %%
# not_to_scale=['columnsname_not_toscale']

#for col in dataset.drop(not_to_scale,axis=1):
#    dataset[col] = preprocessing.scale(dataset[col])

# %% [markdown]
# ## splitting into train and test sets

# %% [markdown]
# Our next step is to divide the data into “attributes” and “labels”. X variable contains all the attributes/features and y variable contains labels.

# %%
X = dataset[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
             'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 
             'density', 'pH', 'sulphates','alcohol']]
y = dataset['quality']

# %% [markdown]
# we split 80% of the data to the training set while 20% of the data to test set

# %%
X_train, X_test, y_train, y_test =train_test_split(X,y, test_size=0.2, random_state=0)

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Multiple Linear Regression

# %%
regressor= LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Model Evaluation

# %%
# Lets get the coefficient for our models
coeff_df = pd.DataFrame(regressor.coef_, X.columns, columns=['Coefficient'])  
coeff_df
# Out:
#                       Coefficient
# fixed acidity            0.106982
# volatile acidity        -1.810325
# citric acid             -0.015163
# residual sugar           0.092914
# chlorides               -0.556724
# free sulfur dioxide      0.004436
# total sulfur dioxide    -0.000287
# density               -188.992556
# pH                       0.822369
# sulphates                0.638976
# alcohol                  0.137843

# %%
print('Coefficients: \n', regressor.coef_)
# Out:
# Coefficients:
#  [ 1.06981517e-01 -1.81032516e+00 -1.51630286e-02  9.29140769e-02
#  -5.56723628e-01  4.43552129e-03 -2.86630409e-04 -1.88992556e+02
#   8.22368627e-01  6.38975597e-01  1.37843182e-01]

# %%
y_pred = regressor.predict( X_test)
plt.scatter(y_test,y_pred)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
# Check the difference between the actual value and predicted value.
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df.head(10)
# Out:
#       Actual  Predicted
# 2762       5   5.590650
# 42         6   5.466122
# 1419       7   6.088268
# 3664       8   6.793538
# 2125       5   5.970548
# 2154       4   4.154233
# 1457       6   6.538580
# 3957       5   6.271539
# 1248       7   5.943391
# 1013       5   5.793337

# %%
# Now let's plot the comparison of Actual and Predicted values
df1= df.head(25)
df1.plot(kind='bar',figsize=(10,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
# Generate Metrics ontest sets
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.6297007608024698
# Mean Squared Error: 0.659845351793594
# Root Mean Squared Error: 0.8123086554959229

# %%
plt.scatter(y_pred, y_test,  color='gray')
# plt.plot(y_test, y_pred, color='red', linewidth=2)
z = np.polyfit(y_pred, y_test, 1)
p = np.poly1d(z)
plt.plot(y_pred,p(y_pred),"r--")
plt.show()

# %%
explainer = shap.LinearExplainer(regressor,X_train)
shap_values = explainer.shap_values(X_train)
shap.force_plot(explainer.expected_value, shap_values[0,:], X_train.iloc[0,:])
shap.summary_plot(shap_values, X_train,axis_color='white')
# Out:
# C:\Users\m_wagle\AppData\Local\Continuum\anaconda3\lib\site-packages\shap\explainers\linear.py:49: UserWarning: The default value for feature_dependence has been changed to "independent"!
#   warnings.warn('The default value for feature_dependence has been changed to "independent"!')

# %%
shap.summary_plot(shap_values, X_test,plot_type='bar',axis_color='white')

# %%
i=0
shap.force_plot(explainer.expected_value, shap_values[i,:], X_train.iloc[i,:])
# Out:
# <div id='iMTDED7PWC4KCO9A6BKER'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...
